# %% [markdown]
# # This contains code for the Linked List side of the analysis (Amit Rai. 4/27/2026/)
#
# **Questions:** What price for each Model of iPhone is fair?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import time


pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 80)

RAW_PATH = 'ecommerce_iphone_resale_cleaned.csv'

rawData = pd.read_csv(RAW_PATH)
rawData.head()
# Out:
#                                                                             title  \
# 0                     Apple iPhone 14 Pro MAX 1 TB Deep purple (Factory Unlocked)
# 1      Apple iPhone 14 Pro Max - 128 GB - ALL COLORS (Unlocked)- Very Good Refurb
# 2                           open box Apple iPhone 14 Pro MAX 256GB FULLY Unlocked
# 3             Apple iPhone 14 -5G - 512GB Factory Unlocked GSM + CDMA - EXCELLENT
# 4  OPEN BOX Apple iPhone 17 A3258 256GB 512GB BLACK SAGE LAVENDER BLUE (Unlocked)
#
#         model_family  generation_number  is_pro  storage_gb_numeric  \
# 0  iPhone 14 Pro Max               14.0    True              1024.0
# 1  iPhone 14 Pro Max               14.0    True               128.0
# 2  iPhone 14 Pro Max               14.0    True               256.0
# 3          iPhone 14               14.0   False               512.0
# 4          iPhone 17               17.0   False               256.0
#
#                  condition   price  wasPrice  price_discount_pct  available  \
# 0                     Used  628.99       NaN                 NaN        0.0
# 1  Very Good - Refurbished  469.99       NaN                 NaN        5.0
# 2                 Open Box  729.99       NaN                 NaN        0.0
# 3  Excellent - Refurbished  397.48       NaN                 NaN        9.0
# 4                 Open Box  779.00       NaN                 NaN        0.0
#
#    sold  was_lot
# 0   1.0    False
# 1   2.0    False
# 2   2.0    False
# 3  30.0    False
# 4  48.0    False
